# %% [markdown]
# # Desafío:

# %% [markdown]
# #### Conociendo Numpy:

# %% [markdown]
# Ha llegado el momento de poner a prueba los conocimientos adquiridos durante la lección. Para ello, vamos a utilizar otro conjunto de datos en un desafío que se desarrollará a lo largo del curso. Este conjunto de datos es una versión modificada del archivo disponible en el sitio de Kaggle(
# https://www.kaggle.com/datasets/joshmcadams/oranges-vs-grapefruit). Por lo tanto, utilizaremos el archivo raw disponible en Github (https://gist.githubusercontent.com/ahcamachod/9be09de793dc3bf1e6c3d98eb4e5b1ef/raw/21b85572693200040e11284ef6dcfc3457ec8e11/citrus.csv
# ).

# %% [markdown]
# En esta etapa, debes cargar los datos. Para hacerlo, importa NumPy y utiliza la función loadtxt. Utiliza el enlace de la URL y el parámetro usecols para omitir la primera columna. Puedes usar np.arange para crear la secuencia de números que representan las columnas. Por último, también es necesario incluir el parámetro skiprows=1 para que la primera línea de texto se omita al leer el archivo.

# %%
import numpy as np

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/9be09de793dc3bf1e6c3d98eb4e5b1ef/raw/21b85572693200040e11284ef6dcfc3457ec8e11/citrus.csv'
array = np.arange(1, 6, 1)  # Selecciona las columnas 1 a 5;
datos = np.loadtxt(url, delimiter=',', usecols=array, skiprows=1)
datos
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]], shape=(10000, 5))

# %% [markdown]
# #### Exploración de Datos:

# %% [markdown]
# Ha llegado el momento de poner a prueba los conocimientos adquiridos durante la lección. Continuando con el proyecto de las naranjas/toronjas, ahora debes seleccionar parte de los datos. Las columnas que evaluaremos son el diámetro y el peso. Crea arrays específicos para almacenar el diámetro y el peso de la naranja y la toronja. El diámetro está en la columna cero y el peso en la columna uno. Los datos de las naranjas van hasta la fila 4999 y los datos de las toronjas comienzan en la fila 5000 del archivo.
#
# Después de seleccionar los datos, importa la biblioteca matplotlib y crea un gráfico para el peso en función del diámetro tanto para las naranjas como para las toronjas.

# %%
dimensiones = datos.ndim
dimensiones
# Out:
# 2

# %%
formato = datos.shape
formato
# Out:
# (10000, 5)

# %% [markdown]
# - Slice Notation:

# %%
diametro_naranja = datos[:5000, 0]
diametro_toronja = datos[5000:, 0]
peso_naranja = datos[:5000, 1]
peso_toronja = datos[5000:, 1]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(diametro_naranja, peso_naranja)
plt.plot(diametro_toronja, peso_toronja)
plt.xlabel('Diámetro (cm)')
plt.ylabel('Peso (g)')
plt.title('Diámetro vs Peso de Naranjas y Toronjas')
plt.legend(['Naranjas', 'Toronjas'])

# %% [markdown]
# #### Operaciones entre Arrays:

# %% [markdown]
# Ha llegado el momento de poner a prueba los conocimientos adquiridos durante la lección. Continuando con el proyecto de las naranjas/toronjas, ahora debes calcular el coeficiente angular y lineal para la recta de las naranjas y para la recta de las toronjas. Utiliza la fórmula de mínimos cuadrados para encontrar cada uno.

# %%
Y = peso_naranja
X = diametro_naranja
n = np.size(X)

a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2)-np.sum(X)**2)
b = np.mean(Y) - a*np.mean(X)

# %%
y = a * X + b
y
# Out:
# array([ 71.1928497 ,  85.25260767,  92.80047774, ..., 213.12240647,
#        216.08235552, 217.85832495], shape=(5000,))

# %%
plt.plot(diametro_naranja, peso_naranja)
plt.plot(X, y)

# %%
Y = peso_toronja
X = diametro_toronja
n = np.size(X)

a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2)-np.sum(X)**2)
b = np.mean(Y) - a*np.mean(X)

# %%
y = a * X + b
y
# Out:
# array([136.86558713, 137.8081178 , 138.27938314, ..., 261.90799009,
#        267.09190881, 275.41759644], shape=(5000,))

# %%
plt.plot(diametro_toronja, peso_toronja)
plt.plot(X, y)

# %% [markdown]
# #### Números Aleatorios:

# %% [markdown]
# Ha llegado el momento de poner a prueba los conocimientos adquiridos durante la lección. Continuando con el proyecto de las naranjas/toronjas, ahora debes calcular el coeficiente angular utilizando la generación de números aleatorios. Supongamos que ya conoces el valor de b y que este es igual a 17.

# %%
norma = np.array([])
np.random.seed(84)
coeficientes_angulares = np.random.uniform(low=0.0, high=30.0, size=100)

for i in range(100):
  norma = np.append(norma, np.linalg.norm(Y - (coeficientes_angulares[i]*X + b)))
  
norma
# Out:
# array([11693.17413134,  3755.7139559 ,  6887.64440213,  2567.54620994,
#        11421.27875572,  9623.16975444,  8570.35712878,  6496.01737355,
#         2576.78335647,  9612.62122283,  5709.22942283,   694.86124391,
#        10855.56971926,  5539.32448104,  3138.48231382,   296.80153318,
#         8897.43610923,  8348.32032632, 10207.45613151, 10229.25483217,
#         2194.04796582,  8447.90009229, 11004.30515345, 11563.83828119,
#         4097.68812039,  7733.20784322,  2802.34672698,  7688.10838526,
#        11135.23528967,  9431.62836349,   725.96495192,  6289.86199437,
#         5189.17243235,  4716.49667303,  9249.97199743,  7274.99619046,
#         8875.70669341,   620.66933013,  4715.68604821,  8050.01059473,
#         9237.81284881,  3993.48369245, 11531.67584557,  5848.61198164,
#         1043.07200636,  9874.87158132, 11758.74209865,  8955.65672563,
#         2219.00875303,  3584.999068  , 11347.09074091,  2478.37746847,
#          878.42012453,  2740.38089117,  1765.67246582,   710.96921152,
#        10067.5710467 ,  6346.6714896 , 12387.56732448,  4279.59974286,
#         6946.52009647,  2906.91365989,   104.85705134,  7559.10881936,
#         4224.13033244,  8179.24895678, 12397.23349888, 11191.49873623,
#         7036.64661416, 10703.55073178, 12508.71843781,  5888.81477298,
#         7254.85666086, 12753.52542699,  4276.72179088,  2052.54166471,
#         8375.92949861,   389.44396221,  5896.4706232 , 10489.37239902,
#         1195.04311666,  6453.77787522,  5254.77362935, 12296.97732174,
#         5899.42877026,  6505.31078723, 10388.75604206,  4879.90044452,
#         7477.98372548,  1220.84625626,  9801.94729056,  1361.08998554,
#          505.97467894,  1003.45606238,  2008.55750242,   371.60103799,
#         2094.24232085,  4659.47814561,  5043.11979783,  4893.43632979])
